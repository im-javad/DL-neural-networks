# %% [markdown]
# # (Batch) Gradient Descent

# %% [markdown]
# - Computes gradient using the whole training sample
# - Slow and computationally expensive algorithm
# - Not suggested for huge training samples
# - Deterministic in nature
# - Gives optimal solution given sufficient time to converge
# - No random shuffling of point are required
# - Can't escape shallow local minima easily
# - Convergence is slow

# %% [markdown]
# ![gradient-descent-variants (3).png](attachment:7dd17e2c-0ed6-4b0a-a19e-58123ed0e785.png)

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# - Compute gradient using a single training sample
# - Faster and less computationally expensive than batch GD
# - Can be used for large training samples
# - Stochastic in nature
# - Gives good solution but not optimal
# - The data sample should be in a random order, and this is why we want to shuffle the training set for every epoch
# - SGD can escape shallow local minima more easily
# - Reach the convergence much faster

# %% [markdown]
# ![gradient-descent-variants.png](attachment:d97861b2-2209-47d3-949e-56d2146d20bc.png)

# %% [markdown]
# # mini-batch Gradient Descent

# %% [markdown]
# - A combination of Stochastic and Batch
# - We set the hyperparameter (the number of how many samples it averages to proceed along the path) based on the GPU cores, so that we neither overfit nor get OOP errors from the GPU

# %% [markdown]
# ![gradient-descent-variants (1).png](attachment:420343f1-2bbc-4b48-8e09-0e00eedc14db.png)
